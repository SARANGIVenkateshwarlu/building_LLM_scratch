# %% [markdown]
# ### Test_libraries

# %%
import sys
print("✅ ACTIVE Python:", sys.executable)
print("✅ In LLM_classification?", "LLM_classification" in sys.executable)
# Out:
# ✅ ACTIVE Python: d:\Krish_AI_projects\building_LLM_scratch\LLM_classification\.venv\Scripts\python.exe
# ✅ In LLM_classification? True

# %%
#!pip install optuna

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import math
import matplotlib.pyplot as plt
from tqdm import tqdm
import importlib.metadata
import pandas as pd
import torch
import numpy as np
import matplotlib
import tiktoken
import optuna
import tensorflow as tf

# %%
print("✅ Python environment test\n")

# PyTorch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

# NumPy
print("NumPy version:", np.__version__)

# Matplotlib
print("Matplotlib version:", matplotlib.__version__)

# tiktoken
print("tiktoken version:", importlib.metadata.version("tiktoken"))

# Basic tensor test
x = torch.randn(3, 3)
print("\nSample tensor:\n", x)

print("\n✅ Environment ready for LLM building!")
# Out:
# ✅ Python environment test
#
# Torch version: 2.11.0+cpu
# CUDA available: False
# NumPy version: 2.0.2
# Matplotlib version: 3.10.8
# tiktoken version: 0.12.0
#
# Sample tensor:
#  tensor([[ 0.2039,  0.4056, -0.6507],
#         [-0.1799,  0.2709,  1.5625],
#         [-0.8475, -1.6131,  2.6207]])
#
# ✅ Environment ready for LLM building!
